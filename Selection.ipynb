# %% [markdown]
# # Data reduction to work

# %%
import os
import pandas as pd

# %%
# Constants
DATA_DIR = "data"
FULL_DATA_DIR = os.path.join("data", "full")


COMPANIES_FILE = os.path.join(FULL_DATA_DIR, "empresas.csv")
PARTNERS_FILE = os.path.join(FULL_DATA_DIR, "socios.csv")
CNAES_FILE = os.path.join(FULL_DATA_DIR, "cnaes_secundarios.csv")
EDUCATION_CODE = 8500000
CNAE_OFFSET = 100000

EDU_COMPANIES_FILE = os.path.join(DATA_DIR, "edu_empresas.csv")
EDU_PARTNERS_FILE = os.path.join(DATA_DIR, "edu_socios.csv")

# %%
chk_size = 100000
iter_companies = pd.read_csv(COMPANIES_FILE, iterator=True, chunksize=chk_size)
index = 0
for chunk in iter_companies:
    edu_chunk = chunk[(chunk['cnae_fiscal']%EDUCATION_CODE) < (CNAE_OFFSET-1)] #CNAE starting with 85
    edu_chunk.to_csv(EDU_COMPANIES_FILE, mode='a', header= True if index == 0 else False)
    index = index + 1
    if index%50 == 0:
        print("chunk number:" , index, "Lines processed:", index*chk_size)
print("Total chunks processed:", index)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (23,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,25,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (23,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 50 Lines processed: 5000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,23,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,23,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,23,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (23,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,23,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,23,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,27,28,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,22,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,22,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,25,26,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 100 Lines processed: 10000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,23,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,7,9,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (25,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,23,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,23,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,22,23,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 150 Lines processed: 15000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,23,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,23,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (23,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 200 Lines processed: 20000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,23,25,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,23,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,23,25,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,22,23,25,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 250 Lines processed: 25000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,23,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 300 Lines processed: 30000000
# chunk number: 350 Lines processed: 35000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,27,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 400 Lines processed: 40000000
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,23,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Total chunks processed: 416

# %%
df_educompanies = pd.read_csv(EDU_COMPANIES_FILE, index_col=0)
df_educompanies.head(10)
# Out:
# 33661084
#            cnpj  matriz_filial  \
# 7732   39000109              1
# 7754   52000168              1
# 7764   62000101              1
# 7768   66000181              1
# 7818  104000287              2
# 7819  104000368              2
# 7824  110000153              1
# 7828  113000278              2
# 7829  113000359              2
# 7839  122000188              1
#
#                                            razao_social  \
# 7732                              MISSAO RAMA DO BRASIL
# 7754  RECREACAO ESCOLA INFANTIL TREVINHO VERDE S/C LTDA
# 7764    CENTRO DE RECREACAO INFANTIL GRILINHO S/C.LTDA.
# 7768          ASSOCIACAO BENEFICENTE LUZ DE UM NOVO DIA
# 7818                           INSTITUTO GRANDE VITORIA
# 7819                           INSTITUTO GRANDE VITORIA
# 7824                             LEONARDO & MODICA LTDA
# 7828      ASSOCIACAO GRUPO DE MAES SOLIDARIAS BEM VIVER
# 7829      ASSOCIACAO GRUPO DE MAES SOLIDARIAS BEM VIVER
# 7839   TAUMATURGO E ALKIMIM RECREACAO INFANTIL S/C LTDA
#
#                                    nome_fantasia  situacao  data_situacao  \
# 7732                                         NaN         2       20041224
# 7754                                         NaN         8       20081231
# 7764                                         NaN         8       19980731
# 7768                                         NaN         2       20081231
# 7818       C.E.I. ''GRANDE VITORIA'' - UNIDADE 1         4       20190321
# 7819     C.E.I. 'ALBERTINA DE SOUSA' - UNIDADE 2         4       20190321
# 7824                                   STEP DATA         4       20190321
# 7828    CENTRO DE EDUCACAO INFANTIL 15 DE AGOSTO         4       20180906
# 7829  CENTRO DE EDUCAO INFANTIL JULIA NASCIMENTO         4       20180906
# 7839                                         NaN         8       20081231
#
#       motivo_situacao nm_cidade_exterior  cod_pais nome_pais  ...  \
# 7732                0                NaN       NaN       NaN  ...
# 7754               71                NaN       NaN       NaN  ...
# 7764                1                NaN       NaN       NaN  ...
# 7768                0                NaN       NaN       NaN  ...
# 7818               63                NaN       NaN       NaN  ...
# 7819               63                NaN       NaN       NaN  ...
# 7824               63                NaN       NaN       NaN  ...
# 7828               63                NaN       NaN       NaN  ...
# 7829               63                NaN       NaN       NaN  ...
# 7839               71                NaN       NaN       NaN  ...
#
#                                  email  qualif_resp  capital_social porte  \
# 7732                               NaN           16             0.0     5
# 7754                               NaN           28             0.0     5
# 7764                               NaN           28             0.0     5
# 7768     CRESCENDOCOMALEGRIA@GMAIL.COM           16             0.0     5
# 7818             fisconta@terra.com.br           16             0.0     5
# 7819             FISCONTA@TERRA.COM.BR           16             0.0     5
# 7824                               NaN           49             0.0     5
# 7828          cris.somater@hotmail.com           16             0.0     5
# 7829  jucelene@kajcontabilidade.com.br           16             0.0     5
# 7839                               NaN           49             0.0     5
#
#      opc_simples data_opc_simples data_exc_simples opc_mei  sit_especial  \
# 7732           0              NaN              NaN       N           NaN
# 7754           0              NaN              NaN       N           NaN
# 7764           0              NaN              NaN       N           NaN
# 7768           0              NaN              NaN       N           NaN
# 7818           0              NaN              NaN     NaN           NaN
# 7819           0              NaN              NaN     NaN           NaN
# 7824           0              NaN              NaN       N           NaN
# 7828           0              NaN              NaN     NaN           NaN
# 7829           0              NaN              NaN     NaN           NaN
# 7839           0              NaN              NaN       N           NaN
#
#      data_sit_especial
# 7732               NaN
# 7754               NaN
# 7764               NaN
# 7768               NaN
# 7818               NaN
# 7819               NaN
# 7824               NaN
# 7828               NaN
# 7829               NaN
# 7839               NaN
#
# [10 rows x 38 columns]

# %%
print(df_educompanies.shape)
# Out:
# (885818, 38)

# %%
companies.columns.values
# Out:
# array(['cnpj', 'matriz_filial', 'razao_social', 'nome_fantasia',
#        'situacao', 'data_situacao', 'motivo_situacao',
#        'nm_cidade_exterior', 'cod_pais', 'nome_pais', 'cod_nat_juridica',
#        'data_inicio_ativ', 'cnae_fiscal', 'tipo_logradouro', 'logradouro',
#        'numero', 'complemento', 'bairro', 'cep', 'uf', 'cod_municipio',
#        'municipio', 'ddd_1', 'telefone_1', 'ddd_2', 'telefone_2',
#        'ddd_fax', 'num_fax', 'email', 'qualif_resp', 'capital_social',
#        'porte', 'opc_simples', 'data_opc_simples', 'data_exc_simples',
#        'opc_mei', 'sit_especial', 'data_sit_especial'], dtype=object)

# %%
# Selecting EDU partners
iter_partners = pd.read_csv(PARTNERS_FILE, iterator=True, chunksize=chk_size)
index = 0
edu_cnpjs = df_educompanies.cnpj
for chunk in iter_partners:
    edu_chunk = chunk[chunk['cnpj'].isin(edu_cnpjs)] #CNAE starting with 85
    edu_chunk.to_csv(EDU_PARTNERS_FILE, mode='a', header= True if index == 0 else False)
    index = index + 1
    if index%10 == 0:
        print("chunk number:" , index, "Lines processed:", index*chk_size)
print("Total chunks processed:", index)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# chunk number: 10 Lines processed: 1000000
# chunk number: 20 Lines processed: 2000000
# chunk number: 30 Lines processed: 3000000
# chunk number: 40 Lines processed: 4000000
# chunk number: 50 Lines processed: 5000000
# chunk number: 60 Lines processed: 6000000
# chunk number: 70 Lines processed: 7000000
# chunk number: 80 Lines processed: 8000000
# chunk number: 90 Lines processed: 9000000
# chunk number: 100 Lines processed: 10000000
# chunk number: 110 Lines processed: 11000000
# chunk number: 120 Lines processed: 12000000
# chunk number: 130 Lines processed: 13000000
# chunk number: 140 Lines processed: 14000000
# chunk number: 150 Lines processed: 15000000
# chunk number: 160 Lines processed: 16000000
# chunk number: 170 Lines processed: 17000000
# chunk number: 180 Lines processed: 18000000
# chunk number: 190 Lines processed: 19000000
# chunk number: 200 Lines processed: 20000000
# chunk number: 210 Lines processed: 21000000
# chunk number: 220 Lines processed: 22000000
# chunk number: 230 Lines processed: 23000000
# chunk number: 240 Lines processed: 24000000
# chunk number: 250 Lines processed: 25000000
# chunk number: 260 Lines processed: 26000000
# Total chunks processed: 262

# %%
df_edupartners = pd.read_csv(EDU_PARTNERS_FILE, index_col=0)
print(df_edupartners.shape)
df_edupartners.head(10)
# Out:
# (610286, 12)
#              cnpj  tipo_socio                  nome_socio cnpj_cpf_socio  \
# 353826   39000109           2    CARLOS ROBERTO PAZ WELLS    ***835158**
# 353860   62000101           2   ROMILDA FARIA DE OLIVEIRA    ***901288**
# 353861   62000101           2    MARCOS CESAR DE OLIVEIRA    ***381868**
# 353866   66000181           2         JOSE PELEGATTI NETO    ***955548**
# 353921  104000287           2  ANDREIA RIBEIRO DOS SANTOS    ***217858**
# 353922  104000368           2  ANDREIA RIBEIRO DOS SANTOS    ***217858**
# 353930  113000278           2   KARINA FERNANDES DE SOUZA    ***165538**
# 353931  113000359           2   KARINA FERNANDES DE SOUZA    ***165538**
# 353948  130000124           2       MARCIO ROSA DE ARAUJO    ***958318**
# 353955  138000271           2    REGILENE GOMES RODRIGUES    ***200518**
#
#         cod_qualificacao  perc_capital  data_entrada  cod_pais_ext  \
# 353826                16           0.0      20050912         249.0
# 353860                28           0.0      19940617         249.0
# 353861                28           0.0      19940617         249.0
# 353866                16           0.0      20181122         249.0
# 353921                16           0.0      20120731         573.0
# 353922                16           0.0      20120731         573.0
# 353930                16           0.0      20100119         386.0
# 353931                16           0.0      20100119         493.0
# 353948                16           0.0      20160502         249.0
# 353955                16           0.0      20130718         137.0
#
#                   nome_pais_ext cpf_repres nome_repres  cod_qualif_repres
# 353826           ESTADOS UNIDOS        NaN         NaN                  0
# 353860           ESTADOS UNIDOS        NaN         NaN                  0
# 353861           ESTADOS UNIDOS        NaN         NaN                  0
# 353866           ESTADOS UNIDOS        NaN         NaN                  0
# 353921  Países Baixos (Holanda)        NaN         NaN                  0
# 353922  Países Baixos (Holanda)        NaN         NaN                  0
# 353930                   ITALIA        NaN         NaN                  0
# 353931                   MEXICO        NaN         NaN                  0
# 353948           ESTADOS UNIDOS        NaN         NaN                  0
# 353955             CAYMAN,ILHAS        NaN         NaN                  0

# %%
pd_partners.columns.values
# Out:
# array(['cnpj', 'tipo_socio', 'nome_socio', 'cnpj_cpf_socio',
#        'cod_qualificacao', 'perc_capital', 'data_entrada', 'cod_pais_ext',
#        'nome_pais_ext', 'cpf_repres', 'nome_repres', 'cod_qualif_repres'],
#       dtype=object)

# %%
df_cnaes = pd.read_csv()
